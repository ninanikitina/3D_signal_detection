# %% [markdown]
# # An Initial Exploration of LIV + UV KASH cells image analysis

# %% [markdown]
# ## Data Loading and Preprocessing

# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
import re
import scipy.stats as stats
from scipy.stats import mannwhitneyu
from itertools import combinations
from statannotations.Annotator import Annotator

# %%
file_path = r"D:\BioLab\Current_experiments\Anamaria_3d_experiment\13.09.2023_analysis_data\cell_stat_verified_0_185.csv"
initial_df = pd.read_csv(file_path)
initial_df = initial_df.dropna(how='all')
initial_df
# Out:
#                                              Image_name  Img_num  Cell_num  \
# 1                      23-5-19 Kash -UV +LIV 0hr-01.czi      0.0       2.0
# 3                      23-5-19 Kash -UV +LIV 0hr-01.czi      0.0       3.0
# 5                      23-5-19 Kash -UV +LIV 0hr-01.czi      0.0       4.0
# 7                      23-5-19 Kash -UV +LIV 0hr-01.czi      0.0       5.0
# 9                      23-5-19 Kash -UV +LIV 0hr-02.czi      1.0       0.0
# ...                                                 ...      ...       ...
# 1781  23-5-19 Kash+doxy 12J -LIV PFA-Triton 48hr-05.czi    185.0       1.0
# 1783  23-5-19 Kash+doxy 12J -LIV PFA-Triton 48hr-05.czi    185.0       2.0
# 1785  23-5-19 Kash+doxy 12J -LIV PFA-Triton 48hr-05.czi    185.0       3.0
# 1787  23-5-19 Kash+doxy 12J -LIV PFA-Triton 48hr-05.czi    185.0       4.0
# 1789  23-5-19 Kash+doxy 12J -LIV PFA-Triton 48hr-05.czi    185.0       5.0
#
#       Nucleus_volume, cubic_micrometre  Nucleus_length, micrometre  \
# 1                          1350.015015                   19.221432
# 3                          1200.007431                   20.412141
# 5                          1724.815610                   22.028102
# 7                          1642.387845                   23.559012
# 9                          1012.737320                   19.306483
# ...                                ...                         ...
# 1781                        387.257762                   12.842638
# 1783                        745.307939                   21.347697
# 1785                        410.168135                   21.602849
# 1787                        441.702445                   26.025479
# 1789                        642.652563                   14.798802
#
#       Nucleus_width, micrometre  Nucleus_high, micrometre  \
# 1                     22.538405                      6.67
# 3                     20.667292                      6.21
# 5                     24.239417                      6.67
# 7                     25.260024                      6.67
# 9                     22.623456                      4.83
# ...                         ...                       ...
# 1781                  32.659425                      4.14
# 1783                  35.295993                      3.68
# 1785                  33.850133                      2.76
# 1787                  33.935184                      2.53
# 1789                  39.888725                      4.37
#
#       Cy5-T1 av_signal_in_nuc_area_3D Cy5-T1 has ring  \
# 1                         5794.978028           False
# 3                         5979.380539           False
# 5                         6190.649713           False
# 7                         5687.317662           False
# 9                         7346.798319           False
# ...                               ...             ...
# 1781                      2025.239333           False
# 1783                      2381.729429           False
# 1785                      1583.480828           False
# 1787                      1525.380570           False
# 1789                      2739.667223           False
#
#       Cy5-T1 ring intensity coef  AF594-T2 av_signal_in_nuc_area_3D  \
# 1                       0.308055                         149.956310
# 3                       0.257681                         160.995917
# 5                       0.194155                         156.400194
# 7                       0.279658                         165.852423
# 9                       0.423900                         183.742148
# ...                          ...                                ...
# 1781                    0.309760                         221.535771
# 1783                    0.135390                         247.366577
# 1785                    0.183329                         281.035687
# 1787                    0.338432                         202.769873
# 1789                    0.086818                         227.838039
#
#      AF594-T2 has ring  AF594-T2 ring intensity coef  \
# 1                False                      0.727957
# 3                False                      0.685988
# 5                False                      0.679126
# 7                False                      0.776251
# 9                False                      0.851247
# ...                ...                           ...
# 1781             False                      0.737609
# 1783             False                      0.756745
# 1785             False                      0.597232
# 1787             False                      0.704978
# 1789             False                      0.565270
#
#       AF488-T3 av_signal_in_nuc_area_3D AF488-T3 has ring  \
# 1                            252.699393             False
# 3                            267.338924             False
# 5                            294.071809             False
# 7                            291.047835             False
# 9                            409.118310             False
# ...                                 ...               ...
# 1781                        2568.726308             False
# 1783                        1644.706516             False
# 1785                        1858.514348             False
# 1787                        1826.428664             False
# 1789                        2008.525461             False
#
#       AF488-T3 ring intensity coef
# 1                         0.495211
# 3                         0.496859
# 5                         0.413096
# 7                         0.713376
# 9                         0.601088
# ...                            ...
# 1781                      0.281261
# 1783                      0.166449
# 1785                      0.148566
# 1787                      0.213817
# 1789                      0.114062
#
# [895 rows x 16 columns]

# %%
def extract_info(image_name):
    date_pattern = re.compile(r'\d+-\d+-\d+')
    date = date_pattern.search(image_name).group(0)

    doxy = "+doxy" if "+doxy" in image_name else "-doxy"

    liv = "+LIV" if "+LIV" in image_name else "-LIV"

    uv = "UV" if "12J" in image_name else "Control"

    time_pattern = re.compile(r'0hr|24hr|48hr')
    time = time_pattern.search(image_name).group(0)

    return pd.Series([date, doxy, liv, uv, time], index=['Date', 'Doxy', 'LIV', 'UV', 'Time'])

# %%
# Extract the information into temporary DataFrame
temp_df = initial_df['Image_name'].apply(extract_info)

# Find the index of the "Image_name" column
idx = initial_df.columns.get_loc('Image_name') + 1

# Insert the new columns
for col in reversed(temp_df.columns):
    initial_df.insert(loc=idx, column=col, value=temp_df[col])

# %%
initial_df
# Out:
#                                              Image_name     Date   Doxy   LIV  \
# 1                      23-5-19 Kash -UV +LIV 0hr-01.czi  23-5-19  -doxy  +LIV
# 3                      23-5-19 Kash -UV +LIV 0hr-01.czi  23-5-19  -doxy  +LIV
# 5                      23-5-19 Kash -UV +LIV 0hr-01.czi  23-5-19  -doxy  +LIV
# 7                      23-5-19 Kash -UV +LIV 0hr-01.czi  23-5-19  -doxy  +LIV
# 9                      23-5-19 Kash -UV +LIV 0hr-02.czi  23-5-19  -doxy  +LIV
# ...                                                 ...      ...    ...   ...
# 1781  23-5-19 Kash+doxy 12J -LIV PFA-Triton 48hr-05.czi  23-5-19  +doxy  -LIV
# 1783  23-5-19 Kash+doxy 12J -LIV PFA-Triton 48hr-05.czi  23-5-19  +doxy  -LIV
# 1785  23-5-19 Kash+doxy 12J -LIV PFA-Triton 48hr-05.czi  23-5-19  +doxy  -LIV
# 1787  23-5-19 Kash+doxy 12J -LIV PFA-Triton 48hr-05.czi  23-5-19  +doxy  -LIV
# 1789  23-5-19 Kash+doxy 12J -LIV PFA-Triton 48hr-05.czi  23-5-19  +doxy  -LIV
#
#            UV  Time  Img_num  Cell_num  Nucleus_volume, cubic_micrometre  \
# 1     Control   0hr      0.0       2.0                       1350.015015
# 3     Control   0hr      0.0       3.0                       1200.007431
# 5     Control   0hr      0.0       4.0                       1724.815610
# 7     Control   0hr      0.0       5.0                       1642.387845
# 9     Control   0hr      1.0       0.0                       1012.737320
# ...       ...   ...      ...       ...                               ...
# 1781       UV  48hr    185.0       1.0                        387.257762
# 1783       UV  48hr    185.0       2.0                        745.307939
# 1785       UV  48hr    185.0       3.0                        410.168135
# 1787       UV  48hr    185.0       4.0                        441.702445
# 1789       UV  48hr    185.0       5.0                        642.652563
#
#       Nucleus_length, micrometre  ...  Nucleus_high, micrometre  \
# 1                      19.221432  ...                      6.67
# 3                      20.412141  ...                      6.21
# 5                      22.028102  ...                      6.67
# 7                      23.559012  ...                      6.67
# 9                      19.306483  ...                      4.83
# ...                          ...  ...                       ...
# 1781                   12.842638  ...                      4.14
# 1783                   21.347697  ...                      3.68
# 1785                   21.602849  ...                      2.76
# 1787                   26.025479  ...                      2.53
# 1789                   14.798802  ...                      4.37
#
#       Cy5-T1 av_signal_in_nuc_area_3D  Cy5-T1 has ring  \
# 1                         5794.978028            False
# 3                         5979.380539            False
# 5                         6190.649713            False
# 7                         5687.317662            False
# 9                         7346.798319            False
# ...                               ...              ...
# 1781                      2025.239333            False
# 1783                      2381.729429            False
# 1785                      1583.480828            False
# 1787                      1525.380570            False
# 1789                      2739.667223            False
#
#      Cy5-T1 ring intensity coef  AF594-T2 av_signal_in_nuc_area_3D  \
# 1                      0.308055                         149.956310
# 3                      0.257681                         160.995917
# 5                      0.194155                         156.400194
# 7                      0.279658                         165.852423
# 9                      0.423900                         183.742148
# ...                         ...                                ...
# 1781                   0.309760                         221.535771
# 1783                   0.135390                         247.366577
# 1785                   0.183329                         281.035687
# 1787                   0.338432                         202.769873
# 1789                   0.086818                         227.838039
#
#       AF594-T2 has ring AF594-T2 ring intensity coef  \
# 1                 False                     0.727957
# 3                 False                     0.685988
# 5                 False                     0.679126
# 7                 False                     0.776251
# 9                 False                     0.851247
# ...                 ...                          ...
# 1781              False                     0.737609
# 1783              False                     0.756745
# 1785              False                     0.597232
# 1787              False                     0.704978
# 1789              False                     0.565270
#
#       AF488-T3 av_signal_in_nuc_area_3D  AF488-T3 has ring  \
# 1                            252.699393              False
# 3                            267.338924              False
# 5                            294.071809              False
# 7                            291.047835              False
# 9                            409.118310              False
# ...                                 ...                ...
# 1781                        2568.726308              False
# 1783                        1644.706516              False
# 1785                        1858.514348              False
# 1787                        1826.428664              False
# 1789                        2008.525461              False
#
#      AF488-T3 ring intensity coef
# 1                        0.495211
# 3                        0.496859
# 5                        0.413096
# 7                        0.713376
# 9                        0.601088
# ...                           ...
# 1781                     0.281261
# 1783                     0.166449
# 1785                     0.148566
# 1787                     0.213817
# 1789                     0.114062
#
# [895 rows x 21 columns]

# %%
initial_df.columns
# Out:
# Index(['Image_name', 'Date', 'Doxy', 'LIV', 'UV', 'Time', 'Img_num',
#        'Cell_num', 'Nucleus_volume, cubic_micrometre',
#        'Nucleus_length, micrometre', 'Nucleus_width, micrometre',
#        'Nucleus_high, micrometre', 'Cy5-T1 av_signal_in_nuc_area_3D',
#        'Cy5-T1 has ring', 'Cy5-T1 ring intensity coef',
#        'AF594-T2 av_signal_in_nuc_area_3D', 'AF594-T2 has ring',
#        'AF594-T2 ring intensity coef', 'AF488-T3 av_signal_in_nuc_area_3D',
#        'AF488-T3 has ring', 'AF488-T3 ring intensity coef'],
#       dtype='object')

# %%
filtered_df = initial_df[['Doxy', 'LIV', 'UV', 'Time', 'Nucleus_volume, cubic_micrometre',
       'Nucleus_length, micrometre', 'Nucleus_width, micrometre',
       'Nucleus_high, micrometre', 'AF594-T2 av_signal_in_nuc_area_3D', 'AF594-T2 has ring',
       'AF594-T2 ring intensity coef', 'AF488-T3 av_signal_in_nuc_area_3D']]

# %%
correlation_matrix = filtered_df.corr()
plt.figure(figsize=(12, 9)) # Set the size to 15 inches wide and 10 inches tall
sns.heatmap(correlation_matrix, annot=True)
plt.show()

# %%
filtered_df['Group'] = filtered_df['Doxy'] + ', ' + filtered_df['LIV'] + ', ' + filtered_df['UV'] + ', '+ ', ' + filtered_df['Time']
plt.figure(figsize=(15, 10))
sns.boxplot(x='Group', y='AF488-T3 av_signal_in_nuc_area_3D', data=filtered_df)
plt.title('Distribution of AF488-T3 av_signal_in_nuc_area_3D across groups')
plt.xticks(rotation=45) # Rotate x-axis labels for better visibility
plt.show()
# Out:
# C:\Users\nnina\AppData\Local\Temp\ipykernel_33480\2363245886.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   filtered_df['Group'] = filtered_df['Doxy'] + ', ' + filtered_df['LIV'] + ', ' + filtered_df['UV'] + ', '+ ', ' + filtered_df['Time']

# %%
filtered_df['AF488-T3 Volume_corrected_signal_in_nuc_area_3D'] = filtered_df['AF488-T3 av_signal_in_nuc_area_3D'] * filtered_df['Nucleus_volume, cubic_micrometre']
# Out:
# C:\Users\nnina\AppData\Local\Temp\ipykernel_33480\673853883.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   filtered_df['AF488-T3 Volume_corrected_signal_in_nuc_area_3D'] = filtered_df['AF488-T3 av_signal_in_nuc_area_3D'] * filtered_df['Nucleus_volume, cubic_micrometre']

# %%
filtered_df['Group'] = filtered_df['Doxy'] + ', ' + filtered_df['LIV'] + ', ' + filtered_df['UV'] + ', ' + filtered_df['Time']
plt.figure(figsize=(15, 10))
sns.boxplot(x='Group', y='AF488-T3 Volume_corrected_signal_in_nuc_area_3D', data=filtered_df)
plt.title('Distribution of AF488-T3 Volume_corrected_signal_in_nuc_area_3D')
plt.xticks(rotation=45) # Rotate x-axis labels for better visibility
plt.show()
# Out:
# C:\Users\nnina\AppData\Local\Temp\ipykernel_33480\4239848785.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   filtered_df['Group'] = filtered_df['Doxy'] + ', ' + filtered_df['LIV'] + ', ' + filtered_df['UV'] + ', ' + filtered_df['Time']

# %%
import csv
RING_CUTT_OFF_COEF = 1
filtered_df['AF594-T2 has ring'] = filtered_df['AF594-T2 ring intensity coef'] >= RING_CUTT_OFF_COEF

with pd.ExcelWriter('raw_data.xlsx') as writer:
    filtered_df.to_excel(writer, index=False)


filtered_df.to_csv('raw_data_anti_spd.csv', index=False, quoting=csv.QUOTE_NONNUMERIC)
# Out:
# C:\Users\nnina\AppData\Local\Temp\ipykernel_33480\2722553577.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   filtered_df['AF594-T2 has ring'] = filtered_df['AF594-T2 ring intensity coef'] >= RING_CUTT_OFF_COEF

# %%
filtered_df
# Out:
#        Doxy   LIV       UV  Time  Nucleus_volume, cubic_micrometre  \
# 1     -doxy  +LIV  Control   0hr                       1350.015015
# 3     -doxy  +LIV  Control   0hr                       1200.007431
# 5     -doxy  +LIV  Control   0hr                       1724.815610
# 7     -doxy  +LIV  Control   0hr                       1642.387845
# 9     -doxy  +LIV  Control   0hr                       1012.737320
# ...     ...   ...      ...   ...                               ...
# 1781  +doxy  -LIV       UV  48hr                        387.257762
# 1783  +doxy  -LIV       UV  48hr                        745.307939
# 1785  +doxy  -LIV       UV  48hr                        410.168135
# 1787  +doxy  -LIV       UV  48hr                        441.702445
# 1789  +doxy  -LIV       UV  48hr                        642.652563
#
#       Nucleus_length, micrometre  Nucleus_width, micrometre  \
# 1                      19.221432                  22.538405
# 3                      20.412141                  20.667292
# 5                      22.028102                  24.239417
# 7                      23.559012                  25.260024
# 9                      19.306483                  22.623456
# ...                          ...                        ...
# 1781                   12.842638                  32.659425
# 1783                   21.347697                  35.295993
# 1785                   21.602849                  33.850133
# 1787                   26.025479                  33.935184
# 1789                   14.798802                  39.888725
#
#       Nucleus_high, micrometre  AF594-T2 av_signal_in_nuc_area_3D  \
# 1                         6.67                         149.956310
# 3                         6.21                         160.995917
# 5                         6.67                         156.400194
# 7                         6.67                         165.852423
# 9                         4.83                         183.742148
# ...                        ...                                ...
# 1781                      4.14                         221.535771
# 1783                      3.68                         247.366577
# 1785                      2.76                         281.035687
# 1787                      2.53                         202.769873
# 1789                      4.37                         227.838039
#
#       AF594-T2 has ring  AF594-T2 ring intensity coef  \
# 1                 False                      0.727957
# 3                 False                      0.685988
# 5                 False                      0.679126
# 7                 False                      0.776251
# 9                 False                      0.851247
# ...                 ...                           ...
# 1781              False                      0.737609
# 1783              False                      0.756745
# 1785              False                      0.597232
# 1787              False                      0.704978
# 1789              False                      0.565270
#
#       AF488-T3 av_signal_in_nuc_area_3D                      Group  \
# 1                            252.699393  -doxy, +LIV, Control, 0hr
# 3                            267.338924  -doxy, +LIV, Control, 0hr
# 5                            294.071809  -doxy, +LIV, Control, 0hr
# 7                            291.047835  -doxy, +LIV, Control, 0hr
# 9                            409.118310  -doxy, +LIV, Control, 0hr
# ...                                 ...                        ...
# 1781                        2568.726308      +doxy, -LIV, UV, 48hr
# 1783                        1644.706516      +doxy, -LIV, UV, 48hr
# 1785                        1858.514348      +doxy, -LIV, UV, 48hr
# 1787                        1826.428664      +doxy, -LIV, UV, 48hr
# 1789                        2008.525461      +doxy, -LIV, UV, 48hr
#
#       AF488-T3 Volume_corrected_signal_in_nuc_area_3D
# 1                                        3.411480e+05
# 3                                        3.208087e+05
# 5                                        5.072196e+05
# 7                                        4.780134e+05
# 9                                        4.143294e+05
# ...                                               ...
# 1781                                     9.947592e+05
# 1783                                     1.225813e+06
# 1785                                     7.623034e+05
# 1787                                     8.067380e+05
# 1789                                     1.290784e+06
#
# [895 rows x 14 columns]

# %%
import seaborn as sns
import matplotlib.pyplot as plt

plt.figure(figsize=(15, 10))

# Extract the order in which seaborn plots the groups
order = sorted(filtered_df['Group'].unique())

# Boxplot with fixed order
sns.boxplot(x='Group', y='AF488-T3 Volume_corrected_signal_in_nuc_area_3D', data=filtered_df, order=order)

# Calculate the means and SDs for each group
group_means = filtered_df.groupby('Group')['AF488-T3 Volume_corrected_signal_in_nuc_area_3D'].mean().reindex(order)
group_stds = filtered_df.groupby('Group')['AF488-T3 Volume_corrected_signal_in_nuc_area_3D'].std().reindex(order)

# Define a consistent height for all the text labels
label_height = 8000000  # Some margin above the maximum value

# Display the means and SDs at the consistent height
for i, (group, mean) in enumerate(group_means.iteritems()):
    plt.text(i, label_height, f"{mean:.0f}", ha='center', color='red', fontsize=9)
    plt.text(i, label_height - 200000, f"±{group_stds[group]:.0f}", ha='center', color='blue', fontsize=9)

plt.title('Distribution of AF488-T3 Volume_corrected_signal_in_nuc_area_3D \nNo background correction \nWithout ring/no-ring correction')
plt.xticks(rotation=45) # Rotate x-axis labels for better visibility
plt.savefig('figures/ANTI_SPD_Distribution of AF488-T3 Volume_corrected_signal_in_nuc_area_3D.png', dpi=300, bbox_inches='tight')
plt.show()

# %%
filtered_df.groupby('Group').count()
# Out:
#                             Doxy  LIV  UV  Time  \
# Group
# +doxy, +LIV, Control, 0hr     25   25  25    25
# +doxy, +LIV, Control, 48hr    54   54  54    54
# +doxy, +LIV, UV, 0hr          53   53  53    53
# +doxy, +LIV, UV, 24hr         44   44  44    44
# +doxy, +LIV, UV, 48hr         53   53  53    53
# +doxy, -LIV, Control, 0hr     52   52  52    52
# +doxy, -LIV, Control, 24hr     7    7   7     7
# +doxy, -LIV, Control, 48hr    48   48  48    48
# +doxy, -LIV, UV, 0hr          57   57  57    57
# +doxy, -LIV, UV, 24hr         33   33  33    33
# +doxy, -LIV, UV, 48hr         14   14  14    14
# -doxy, +LIV, Control, 0hr     29   29  29    29
# -doxy, +LIV, Control, 48hr    71   71  71    71
# -doxy, +LIV, UV, 0hr          60   60  60    60
# -doxy, +LIV, UV, 48hr         30   30  30    30
# -doxy, -LIV, Control, 0hr     35   35  35    35
# -doxy, -LIV, Control, 48hr    61   61  61    61
# -doxy, -LIV, UV, 0hr          48   48  48    48
# -doxy, -LIV, UV, 24hr         88   88  88    88
# -doxy, -LIV, UV, 48hr         33   33  33    33
#
#                             Nucleus_volume, cubic_micrometre  \
# Group
# +doxy, +LIV, Control, 0hr                                 25
# +doxy, +LIV, Control, 48hr                                54
# +doxy, +LIV, UV, 0hr                                      53
# +doxy, +LIV, UV, 24hr                                     44
# +doxy, +LIV, UV, 48hr                                     53
# +doxy, -LIV, Control, 0hr                                 52
# +doxy, -LIV, Control, 24hr                                 7
# +doxy, -LIV, Control, 48hr                                48
# +doxy, -LIV, UV, 0hr                                      57
# +doxy, -LIV, UV, 24hr                                     33
# +doxy, -LIV, UV, 48hr                                     14
# -doxy, +LIV, Control, 0hr                                 29
# -doxy, +LIV, Control, 48hr                                71
# -doxy, +LIV, UV, 0hr                                      60
# -doxy, +LIV, UV, 48hr                                     30
# -doxy, -LIV, Control, 0hr                                 35
# -doxy, -LIV, Control, 48hr                                61
# -doxy, -LIV, UV, 0hr                                      48
# -doxy, -LIV, UV, 24hr                                     88
# -doxy, -LIV, UV, 48hr                                     33
#
#                             Nucleus_length, micrometre  \
# Group
# +doxy, +LIV, Control, 0hr                           25
# +doxy, +LIV, Control, 48hr                          54
# +doxy, +LIV, UV, 0hr                                53
# +doxy, +LIV, UV, 24hr                               44
# +doxy, +LIV, UV, 48hr                               53
# +doxy, -LIV, Control, 0hr                           52
# +doxy, -LIV, Control, 24hr                           7
# +doxy, -LIV, Control, 48hr                          48
# +doxy, -LIV, UV, 0hr                                57
# +doxy, -LIV, UV, 24hr                               33
# +doxy, -LIV, UV, 48hr                               14
# -doxy, +LIV, Control, 0hr                           29
# -doxy, +LIV, Control, 48hr                          71
# -doxy, +LIV, UV, 0hr                                60
# -doxy, +LIV, UV, 48hr                               30
# -doxy, -LIV, Control, 0hr                           35
# -doxy, -LIV, Control, 48hr                          61
# -doxy, -LIV, UV, 0hr                                48
# -doxy, -LIV, UV, 24hr                               88
# -doxy, -LIV, UV, 48hr                               33
#
#                             Nucleus_width, micrometre  \
# Group
# +doxy, +LIV, Control, 0hr                          25
# +doxy, +LIV, Control, 48hr                         54
# +doxy, +LIV, UV, 0hr                               53
# +doxy, +LIV, UV, 24hr                              44
# +doxy, +LIV, UV, 48hr                              53
# +doxy, -LIV, Control, 0hr                          52
# +doxy, -LIV, Control, 24hr                          7
# +doxy, -LIV, Control, 48hr                         48
# +doxy, -LIV, UV, 0hr                               57
# +doxy, -LIV, UV, 24hr                              33
# +doxy, -LIV, UV, 48hr                              14
# -doxy, +LIV, Control, 0hr                          29
# -doxy, +LIV, Control, 48hr                         71
# -doxy, +LIV, UV, 0hr                               60
# -doxy, +LIV, UV, 48hr                              30
# -doxy, -LIV, Control, 0hr                          35
# -doxy, -LIV, Control, 48hr                         61
# -doxy, -LIV, UV, 0hr                               48
# -doxy, -LIV, UV, 24hr                              88
# -doxy, -LIV, UV, 48hr                              33
#
#                             Nucleus_high, micrometre  \
# Group
# +doxy, +LIV, Control, 0hr                         25
# +doxy, +LIV, Control, 48hr                        54
# +doxy, +LIV, UV, 0hr                              53
# +doxy, +LIV, UV, 24hr                             44
# +doxy, +LIV, UV, 48hr                             53
# +doxy, -LIV, Control, 0hr                         52
# +doxy, -LIV, Control, 24hr                         7
# +doxy, -LIV, Control, 48hr                        48
# +doxy, -LIV, UV, 0hr                              57
# +doxy, -LIV, UV, 24hr                             33
# +doxy, -LIV, UV, 48hr                             14
# -doxy, +LIV, Control, 0hr                         29
# -doxy, +LIV, Control, 48hr                        71
# -doxy, +LIV, UV, 0hr                              60
# -doxy, +LIV, UV, 48hr                             30
# -doxy, -LIV, Control, 0hr                         35
# -doxy, -LIV, Control, 48hr                        61
# -doxy, -LIV, UV, 0hr                              48
# -doxy, -LIV, UV, 24hr                             88
# -doxy, -LIV, UV, 48hr                             33
#
#                             AF594-T2 av_signal_in_nuc_area_3D  \
# Group
# +doxy, +LIV, Control, 0hr                                  25
# +doxy, +LIV, Control, 48hr                                 54
# +doxy, +LIV, UV, 0hr                                       53
# +doxy, +LIV, UV, 24hr                                      44
# +doxy, +LIV, UV, 48hr                                      53
# +doxy, -LIV, Control, 0hr                                  52
# +doxy, -LIV, Control, 24hr                                  7
# +doxy, -LIV, Control, 48hr                                 48
# +doxy, -LIV, UV, 0hr                                       57
# +doxy, -LIV, UV, 24hr                                      33
# +doxy, -LIV, UV, 48hr                                      14
# -doxy, +LIV, Control, 0hr                                  29
# -doxy, +LIV, Control, 48hr                                 71
# -doxy, +LIV, UV, 0hr                                       60
# -doxy, +LIV, UV, 48hr                                      30
# -doxy, -LIV, Control, 0hr                                  35
# -doxy, -LIV, Control, 48hr                                 61
# -doxy, -LIV, UV, 0hr                                       48
# -doxy, -LIV, UV, 24hr                                      88
# -doxy, -LIV, UV, 48hr                                      33
#
#                             AF594-T2 has ring  AF594-T2 ring intensity coef  \
# Group
# +doxy, +LIV, Control, 0hr                  25                            25
# +doxy, +LIV, Control, 48hr                 54                            54
# +doxy, +LIV, UV, 0hr                       53                            53
# +doxy, +LIV, UV, 24hr                      44                            44
# +doxy, +LIV, UV, 48hr                      53                            53
# +doxy, -LIV, Control, 0hr                  52                            52
# +doxy, -LIV, Control, 24hr                  7                             7
# +doxy, -LIV, Control, 48hr                 48                            48
# +doxy, -LIV, UV, 0hr                       57                            57
# +doxy, -LIV, UV, 24hr                      33                            33
# +doxy, -LIV, UV, 48hr                      14                            14
# -doxy, +LIV, Control, 0hr                  29                            29
# -doxy, +LIV, Control, 48hr                 71                            71
# -doxy, +LIV, UV, 0hr                       60                            60
# -doxy, +LIV, UV, 48hr                      30                            30
# -doxy, -LIV, Control, 0hr                  35                            35
# -doxy, -LIV, Control, 48hr                 61                            61
# -doxy, -LIV, UV, 0hr                       48                            48
# -doxy, -LIV, UV, 24hr                      88                            88
# -doxy, -LIV, UV, 48hr                      33                            33
#
#                             AF488-T3 av_signal_in_nuc_area_3D  \
# Group
# +doxy, +LIV, Control, 0hr                                  25
# +doxy, +LIV, Control, 48hr                                 54
# +doxy, +LIV, UV, 0hr                                       53
# +doxy, +LIV, UV, 24hr                                      44
# +doxy, +LIV, UV, 48hr                                      53
# +doxy, -LIV, Control, 0hr                                  52
# +doxy, -LIV, Control, 24hr                                  7
# +doxy, -LIV, Control, 48hr                                 48
# +doxy, -LIV, UV, 0hr                                       57
# +doxy, -LIV, UV, 24hr                                      33
# +doxy, -LIV, UV, 48hr                                      14
# -doxy, +LIV, Control, 0hr                                  29
# -doxy, +LIV, Control, 48hr                                 71
# -doxy, +LIV, UV, 0hr                                       60
# -doxy, +LIV, UV, 48hr                                      30
# -doxy, -LIV, Control, 0hr                                  35
# -doxy, -LIV, Control, 48hr                                 61
# -doxy, -LIV, UV, 0hr                                       48
# -doxy, -LIV, UV, 24hr                                      88
# -doxy, -LIV, UV, 48hr                                      33
#
#                             AF488-T3 Volume_corrected_signal_in_nuc_area_3D
# Group
# +doxy, +LIV, Control, 0hr                                                25
# +doxy, +LIV, Control, 48hr                                               54
# +doxy, +LIV, UV, 0hr                                                     53
# +doxy, +LIV, UV, 24hr                                                    44
# +doxy, +LIV, UV, 48hr                                                    53
# +doxy, -LIV, Control, 0hr                                                52
# +doxy, -LIV, Control, 24hr                                                7
# +doxy, -LIV, Control, 48hr                                               48
# +doxy, -LIV, UV, 0hr                                                     57
# +doxy, -LIV, UV, 24hr                                                    33
# +doxy, -LIV, UV, 48hr                                                    14
# -doxy, +LIV, Control, 0hr                                                29
# -doxy, +LIV, Control, 48hr                                               71
# -doxy, +LIV, UV, 0hr                                                     60
# -doxy, +LIV, UV, 48hr                                                    30
# -doxy, -LIV, Control, 0hr                                                35
# -doxy, -LIV, Control, 48hr                                               61
# -doxy, -LIV, UV, 0hr                                                     48
# -doxy, -LIV, UV, 24hr                                                    88
# -doxy, -LIV, UV, 48hr                                                    33

# %%
import seaborn as sns
import matplotlib.pyplot as plt

# Define the groups
groups_true = [
    '+doxy, +LIV, Control, 0hr',
    '+doxy, +LIV, Control, 48hr',
    '+doxy, +LIV, UV, 0hr',
    '+doxy, +LIV, UV, 24hr',
    '+doxy, +LIV, UV, 48hr',
    '+doxy, -LIV, Control, 0hr',
    '+doxy, -LIV, Control, 24hr',
    '+doxy, -LIV, Control, 48hr',
    '+doxy, -LIV, UV, 0hr',
    '+doxy, -LIV, UV, 24hr',
    '+doxy, -LIV, UV, 48hr',
]

groups_false = [
    '-doxy, +LIV, Control, 0hr',
    '-doxy, +LIV, Control, 48hr',
    '-doxy, +LIV, UV, 0hr',
    '-doxy, +LIV, UV, 48hr',
    '-doxy, -LIV, Control, 0hr',
    '-doxy, -LIV, Control, 48hr',
    '-doxy, -LIV, UV, 0hr',
    '-doxy, -LIV, UV, 24hr',
    '-doxy, -LIV, UV, 48hr',
]

# Filter the DataFrame based on conditions
subset_true = filtered_df[(filtered_df['Group'].isin(groups_true)) & (filtered_df['AF594-T2 has ring'] == True)]
subset_false = filtered_df[(filtered_df['Group'].isin(groups_false)) & (filtered_df['AF594-T2 has ring'] == False)]

# Concatenate both dataframes for a unified plot
combined_df = pd.concat([subset_true, subset_false], ignore_index=True)

# Define colors for each group
colors = sns.color_palette("husl", len(groups_true + groups_false))

# Plot combined boxplots with individual colors
plt.figure(figsize=(20, 10))
sns.boxplot(x='Group', y='AF488-T3 Volume_corrected_signal_in_nuc_area_3D', data=combined_df, palette=colors)

# Labeling
combined_means = combined_df.groupby('Group')['AF488-T3 Volume_corrected_signal_in_nuc_area_3D'].mean().reindex(groups_true + groups_false)
combined_stds = combined_df.groupby('Group')['AF488-T3 Volume_corrected_signal_in_nuc_area_3D'].std().reindex(groups_true + groups_false)

label_height =  6000000

for i, (group, mean) in enumerate(combined_means.iteritems()):
    plt.text(i, label_height, f"{mean:.0f}", ha='center', color='red', fontsize=10)
    plt.text(i, label_height - 200000, f"±{combined_stds[group]:.0f}", ha='center', color='blue', fontsize=10)

plt.title('Combined Distribution of AF488-T3 Volume_corrected_signal_in_nuc_area_3D \nAdjusted to a ring presence: \n+doxy with a ring, -doxy without a ring \n\n')
plt.xticks(rotation=45)
plt.savefig('figures/ANTI_SPD_Distribution of AF488-T3 Volume_corrected_signal_in_nuc_area_3D_ring_no-ring.png', dpi=300, bbox_inches='tight')

plt.show()
